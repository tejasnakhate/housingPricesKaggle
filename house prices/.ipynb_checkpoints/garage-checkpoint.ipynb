# %%
import pandas as pd
import numpy as np

x = pd.read_csv('encoded_X.csv')
y= pd.read_csv('y.csv')

# %%
test = x.iloc[y[y['GarageType'].isna()].index]
test.head()
# Out:
#     Unnamed: 0  Street  MSZoningCODE  LotShapeCODE  LandContourCODE  \
# 39          39       2             3             3                3
# 48          48       2             4             3                3
# 78          78       2             3             3                3
# 88          88       2             0             0                3
# 89          89       2             3             3                3
#
#     UtilitiesCODE  LotConfigCODE  LandSlopeCODE  NeighborhoodCODE  \
# 39              0              4              0                 7
# 48              0              4              0                17
# 78              0              4              0                19
# 88              0              0              0                 9
# 89              0              4              0                 5
#
#     Condition1CODE  ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 39               2  ...           0            0              0          0
# ...

# %%
y['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
ind=y[y['GarageType'].isna()].index
bad_df = y.index.isin(ind)
p=pd.concat([x,y], axis = 1)
t1=y[~bad_df]
t2=x[~bad_df]
test = x[bad_df]
# obj_df["body_style"] = obj_df["body_style"].astype('category')
t1_bkp=t1
t1=t1.astype('category')
t1["GarageTypeCode"]=t1['GarageType'].cat.codes
t1["GarageCondCode"]=t1['GarageCond'].cat.codes
t1["GarageQualCode"]=t1['GarageQual'].cat.codes
t1["GarageFinishCode"]=t1['GarageFinish'].cat.codes
t1["FireplaceQuCode"]=t1['FireplaceQu'].cat.codes
t1["ElectricalCode"]=t1['Electrical'].cat.codes
t1["BsmtFinType2Code"]=t1['BsmtFinType2'].cat.codes
t1["BsmtFinType1Code"]=t1['BsmtFinType1'].cat.codes
t1["BsmtExposureCode"]=t1['BsmtExposure'].cat.codes
t1["BsmtCondCode"]=t1['BsmtCond'].cat.codes
t1["BsmtQualCode"]=t1['BsmtQual'].cat.codes
t1["MasVnrTypeCode"]=t1['MasVnrType'].cat.codes

# %%
t1.columns
txt = ['Unnamed: 0','MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
       'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu',
       'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
t1=t1.drop(columns=txt, axis=1)
t1.head()
# Out:
#    GarageTypeCode  GarageCondCode  GarageQualCode  GarageFinishCode  \
# 0               1               4               4                 1
# 1               1               4               4                 1
# 2               1               4               4                 1
# 3               5               4               4                 2
# 4               1               4               4                 1
#
#    FireplaceQuCode  ElectricalCode  BsmtFinType2Code  BsmtFinType1Code  \
# 0               -1               4                 5                 2
# 1                4               4                 5                 0
# 2                4               4                 5                 2
# 3                2               4                 5                 0
# 4                4               4                 5                 2
#
#    BsmtExposureCode  BsmtCondCode  BsmtQualCode  MasVnrTypeCode
# 0                 3             3             2               1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
for i in t1:
    model.fit(t2,t1[i])
    predict = model.predict(test)
    preds[i] = predict

# %%
# preds = pd.DataFrame(data = GARAGETYPE)
# preds["GARAGETYPE"] = GARAGETYPE
# preds = preds.drop([0],axis=1)
# preds["GarageQualCode"] = GarageQualCode
pd.set_option('display.max_rows', 100)
# preds = preds.drop(['0'], axis = 1)
preds
# Out:
#     GarageTypeCode  GarageCondCode  GarageQualCode  GarageFinishCode  \
# 0                5               4               4                 2
# 1                5               4               4                 2
# 2                5               4               4                 2
# 3                5               1               4                 2
# 4                5               4               4                 2
# 5                1               4               4                 2
# 6                5               4               4                 2
# 7                5               4               4                 2
# 8                5               4               4                 2
# 9                5               4               4                 2
# 10               1               4               4                 2
# 11               5               4               1                 2
# 12               5               4               4                 2
# ...

# %%
# test.reset_index(drop=True, inplace=True) 
final_preds = pd.concat([test,preds], axis=1)

# %%
final_preds.shape
# Out:
# (81, 79)

# %%
t2.shape
# Out:
# (1379, 67)

# %%
t1.shape
# Out:
# (1379, 12)

# %%
trainTestMerge = pd.concat([t1,t2], axis=1)
trainTestMerge.shape
# Out:
# (1379, 79)

# %%
final_data = pd.concat([trainTestMerge,final_preds], axis = 0)
final_data.shape
# Out:
# (1460, 79)

# %%
pd.set_option('display.max_rows', 2000)
final_data
# Out:
#       GarageTypeCode  GarageCondCode  GarageQualCode  GarageFinishCode  \
# 0                  1               4               4                 1
# 1                  1               4               4                 1
# 2                  1               4               4                 1
# 3                  5               4               4                 2
# 4                  1               4               4                 1
# 5                  1               4               4                 2
# 6                  1               4               4                 1
# 7                  1               4               4                 1
# 8                  5               4               1                 2
# 9                  1               4               2                 1
# 10                 5               4               4                 2
# 11                 3               4               4                 0
# ...

# %%
####TRAINING FINAL MODEL####
Ytrain = final_data['SalePrice']
Xtrain = final_data
Xtrain = Xtrain.drop(['SalePrice'], axis = 1)
test = pd.read_csv("test.csv")

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5     1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7     1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8     1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9     1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10    1471         120       RH         26.0     5858   Pave   NaN      IR1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
model.fit(Xtrain,Ytrain)
predict = model.predict(test)
pd.set_option('display.max_rows', 2000)
predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-b43717767398> in <module>
#       4                                max_features = 'sqrt')
#       5 model.fit(Xtrain,Ytrain)
# ----> 6 predict = model.predict(test)
#       7 pd.set_option('display.max_rows', 2000)
#       8 predict
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# ...
